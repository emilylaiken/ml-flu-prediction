# %%
import matplotlib.pyplot as plt
import sys

# %%
from evaluate_models import load_data_for_evaluation, load_data2, plot_violins, palette
sys.path.insert(0, '../')
from utils import load_run

# %%
df, results1 = load_data_for_evaluation('city')
# Out:
# loaded file: ../results/no_coefs/results_cities/persistance/1.json
# loaded file: ../results/no_coefs/results_cities/persistance/2.json
# loaded file: ../results/no_coefs/results_cities/persistance/4.json
# loaded file: ../results/no_coefs/results_cities/persistance/8.json
# loaded file: ../results/no_coefs/results_cities/forecasting_ar/1.json
# loaded file: ../results/no_coefs/results_cities/forecasting_ar/2.json
# loaded file: ../results/no_coefs/results_cities/forecasting_ar/4.json
# loaded file: ../results/no_coefs/results_cities/forecasting_ar/8.json
# loaded file: ../results/no_coefs/results_cities/nowcasting_ar/1.json
# loaded file: ../results/no_coefs/results_cities/nowcasting_ar/2.json
# loaded file: ../results/no_coefs/results_cities/nowcasting_ar/4.json
# loaded file: ../results/no_coefs/results_cities/nowcasting_ar/8.json
# loaded file: ../results/no_coefs/results_cities/forecasting_armulti/1.json
# ...

# %%
df, results2 = load_data2('state')
# Out:
# loaded file: ../results/no_coefs/results_states/persistance/1.json
# loaded file: ../results/no_coefs/results_states/persistance/2.json
# loaded file: ../results/no_coefs/results_states/persistance/4.json
# loaded file: ../results/no_coefs/results_states/persistance/8.json
# loaded file: ../results/no_coefs/results_states/forecasting_ar/1.json
# loaded file: ../results/no_coefs/results_states/forecasting_ar/2.json
# loaded file: ../results/no_coefs/results_states/forecasting_ar/4.json
# loaded file: ../results/no_coefs/results_states/forecasting_ar/8.json
# loaded file: ../results/no_coefs/results_states/nowcasting_ar/1.json
# loaded file: ../results/no_coefs/results_states/nowcasting_ar/2.json
# loaded file: ../results/no_coefs/results_states/nowcasting_ar/4.json
# loaded file: ../results/no_coefs/results_states/nowcasting_ar/8.json
# loaded file: ../results/no_coefs/results_states/forecasting_armulti/1.json
# ...

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 6))
plot_violins(ax[0], [results2[model][8] for model in ['persistance', 'forecasting_ar', 'forecasting_armulti', 'forecasting_rf', 'forecasting_lstm']], 'rmse', ['Persistence', 'AR', 'AR-net LR', 'AR-net RF', 'AR-net GRU'], palette)
plot_violins(ax[1], [results2[model][8] for model in ['persistance', 'nowcasting_ar', 'nowcasting_armulti', 'nowcasting_rf', 'nowcasting_lstm']], 'rmse', ['Persistence', 'AR', 'AR-net LR', 'AR-net RF', 'AR-net GRU'], palette)
ax[0].set_ylim(0, 2)
ax[1].set_ylim(0, 2)
plt.show()
# Out:
# /Users/emily/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:598: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   kde_data = remove_na(group_data)
# /Users/emily/anaconda3/lib/python3.6/site-packages/seaborn/categorical.py:826: FutureWarning: remove_na is deprecated and is a private function. Do not use.
#   violin_data = remove_na(group_data)
# /Users/emily/anaconda3/lib/python3.6/site-packages/scipy/stats/stats.py:1633: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
